# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DATA/Advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 3.79679723671522

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.763833333333334

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()

# %%
X_std_scaler = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_std_scaler, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.4945000000000013

# %%
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
scaler = MinMaxScaler()

# %%
X_minmax_scaler = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_minmax_scaler, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.0420000000000003

# %% [markdown]
# # no pipeline

# %%
df = pd.read_csv('../DATA/Advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.6856666666666669

# %%
new_data = np.array([[230, 78, 63]])

# %%
new_data = scaler.transform(new_data)
# Out:
# C:\Users\ASUS\Desktop\ML_LOGIX_\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data
# Out:
# array([[0.88051455, 3.73545887, 1.57831749]])

# %%
model.predict(new_data)
# Out:
# array([25.4])

# %% [markdown]
# # pipeline

# %%
df = pd.read_csv('../DATA/Advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeRegressor()
scaler = StandardScaler()

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([('scaler', scaler), ('model', model)])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', DecisionTreeRegressor())])

# %%
y_pred = pipe.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 1.8668333333333338

# %%
new_data = np.array([[230, 175, 68]])

# %%
pipe.predict(new_data)
# Out:
# C:\Users\ASUS\Desktop\ML_LOGIX_\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([25.4])

# %% [markdown]
# # pipeline + gridsearch + cross validation

# %%
df = pd.read_csv('../DATA/Advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = DecisionTreeRegressor()
scaler = StandardScaler()

# %%
pipe = Pipeline([('scaler', scaler), ('model', model)])

# %%
model_params = {
    "model__criterion" : ["squared_error", "friedman_mse", "absolute_error", "poisson"],
    "model__splitter" : ["best", "random"],
    "model__max_depth": [None, 2, 6, 10]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
final_model = GridSearchCV(pipe, param_grid=model_params, cv=5, verbose=2)

# %%
final_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=squared_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=friedman_mse, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=absolute_error, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=None, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=2, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=6, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=best; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=random; total time=   0.0s
# [CV] END model__criterion=poisson, model__max_depth=10, model__splitter=random; total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model', DecisionTreeRegressor())]),
#              param_grid={'model__criterion': ['squared_error', 'friedman_mse',
#                                               'absolute_error', 'poisson'],
#                          'model__max_depth': [None, 2, 6, 10],
#                          'model__splitter': ['best', 'random']},
#              verbose=2)

# %%
final_model.best_score_
# Out:
# 0.9368280615912326

# %%
final_model.best_estimator_
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', DecisionTreeRegressor(criterion='absolute_error'))])
